# %% [markdown]
# <a href="https://colab.research.google.com/github/Pro5507/ABS-and-Polly/blob/main/Random_Facts(API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url = "https://uselessfacts.jsph.pl/random.json?language=en"
def get_random_technology_fact():
  response = requests.get(url)
  if response.status_code == 200:
    fact_data = response.json()
    print(f"Did you know? {fact_data['text']}")
  else:
    print("Failed to fetch fact")
while True:
  user_input = input("Please press Enter to get random tech fact or type 'q' to quit.")
  if user_input.lower() == 'q':
    break
  get_random_technology_fact()
# Out:
# Please press Enter to get random tech fact or type 'q' to quit.
# Did you know? Most household dust is made of dead skin cells.
# Please press Enter to get random tech fact or type 'q' to quit.
# Did you know? The most common name in world is Mohammed.
# Please press Enter to get random tech fact or type 'q' to quit.
# Did you know? Owls are one of the only birds who can see the color blue!
# Please press Enter to get random tech fact or type 'q' to quit.q
