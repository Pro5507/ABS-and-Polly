# %% [markdown]
# <a href="https://colab.research.google.com/github/Pro5507/ABS-and-Polly/blob/main/Intro_to_NPL(API).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from config import HF_API_KEY

def classify_text(text):
  API_URL = "https://api-interface.huggingface.co/models/distilbert-base-uncased-finetuned-sst-2-english"
  headers = {"Authorization":f"Bearer {85kw6eQCyW5^ca&}"}
  playload = {"inputs": text}
  response = requests.post(API_URL, headers=headers, json=playload)
  return response.json()

if __name__=="__main__":
  sample_text = "I love using Hugging Face APIs!"
  result = classify_text(sample_text)
  print(result)
# Out:
#   File "/tmp/ipython-input-3809970348.py", line 6
#     headers = {"Authorization":f"Bearer {85kw6eQCyW5^ca&}"}
#                                           ^
# SyntaxError: invalid decimal literal
